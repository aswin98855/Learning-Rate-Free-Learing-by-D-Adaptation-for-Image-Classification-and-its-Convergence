# %%
import math
from typing import TYPE_CHECKING, Any, Callable, Optional

import torch
import torch.optim
import pdb
import logging
import os
import torch.distributed as dist

if TYPE_CHECKING:
    from torch.optim.optimizer import _params_t
else:
    _params_t = Any

class DAdaptAdam(torch.optim.Optimizer):
    def __init__(self, params, lr=1.0,
                betas=(0.9, 0.999), eps=1e-8,
                weight_decay=0, log_every=0,
                decouple=False,
                use_bias_correction=False,
                d0=1e-6, growth_rate=float('inf'),
                fsdp_in_use=False):
        if not 0.0 < d0:
            raise ValueError("Invalid d0 value: {}".format(d0))
        if not 0.0 < lr:
            raise ValueError("Invalid learning rate: {}".format(lr))
        if not 0.0 < eps:
            raise ValueError("Invalid epsilon value: {}".format(eps))
        if not 0.0 <= betas[0] < 1.0:
            raise ValueError("Invalid beta parameter at index 0: {}".format(betas[0]))
        if not 0.0 <= betas[1] < 1.0:
            raise ValueError("Invalid beta parameter at index 1: {}".format(betas[1]))

        if decouple:
            print(f"Using decoupled weight decay")


        defaults = dict(lr=lr, betas=betas, eps=eps,
                        weight_decay=weight_decay,
                        d = d0,
                        k=0,
                        layer_scale=1.0,
                        numerator_weighted=0.0,
                        log_every=log_every,
                        growth_rate=growth_rate,
                        use_bias_correction=use_bias_correction,
                        decouple=decouple,
                        fsdp_in_use=fsdp_in_use)
        self.d0 = d0
        super().__init__(params, defaults)

    @property
    def supports_memory_efficient_fp16(self):
        return False

    @property
    def supports_flat_params(self):
        return True

    def step(self, closure=None):
        loss = None
        if closure is not None:
            loss = closure()

        sk_l1 = 0.0

        group = self.param_groups[0]
        use_bias_correction = group['use_bias_correction']
        numerator_weighted = group['numerator_weighted']
        beta1, beta2 = group['betas']
        k = group['k']

        d = group['d']
        lr = max(group['lr'] for group in self.param_groups)

        if use_bias_correction:
            bias_correction = ((1-beta2**(k+1))**0.5)/(1-beta1**(k+1))
        else:
            bias_correction = 1

        dlr = d*lr*bias_correction

        growth_rate = group['growth_rate']
        decouple = group['decouple']
        log_every = group['log_every']
        fsdp_in_use = group['fsdp_in_use']


        sqrt_beta2 = beta2**(0.5)

        numerator_acum = 0.0

        for group in self.param_groups:
            decay = group['weight_decay']
            k = group['k']
            eps = group['eps']
            group_lr = group['lr']
            r = group['layer_scale']

            if group_lr not in [lr, 0.0]:
                raise RuntimeError(f"Setting different lr values in different parameter groups "
                                "is only supported for values of 0. To scale the learning "
                                "rate differently for each layer, set the 'layer_scale' value instead.")

            for p in group['params']:
                if p.grad is None:
                    continue
                if hasattr(p, "_fsdp_flattened"):
                    fsdp_in_use = True

                grad = p.grad.data

                if decay != 0 and not decouple:
                    grad.add_(p.data, alpha=decay)

                state = self.state[p]

                if 'step' not in state:
                    state['step'] = 0
                    state['s'] = torch.zeros_like(p.data).detach()
                    state['exp_avg'] = torch.zeros_like(p.data).detach()
                    state['exp_avg_sq'] = torch.zeros_like(p.data).detach()

                exp_avg, exp_avg_sq = state['exp_avg'], state['exp_avg_sq']

                s = state['s']

                if group_lr > 0.0:
                    denom = exp_avg_sq.sqrt().add_(eps)
                    numerator_acum += r * dlr * torch.dot(grad.flatten(), s.div(denom).flatten()).item()

                    exp_avg.mul_(beta1).add_(grad, alpha=r*dlr*(1-beta1))
                    exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1-beta2)

                    s.mul_(sqrt_beta2).add_(grad, alpha=dlr*(1-sqrt_beta2))
                    sk_l1 += r * s.abs().sum().item()


        numerator_weighted = sqrt_beta2*numerator_weighted + (1-sqrt_beta2)*numerator_acum
        d_hat = d
        if sk_l1 == 0:
            return loss

        if lr > 0.0:
            if fsdp_in_use:
                dist_tensor = torch.zeros(2).cuda()
                dist_tensor[0] = numerator_weighted
                dist_tensor[1] = sk_l1
                dist.all_reduce(dist_tensor, op=dist.ReduceOp.SUM)
                global_numerator_weighted = dist_tensor[0]
                global_sk_l1 = dist_tensor[1]
            else:
                global_numerator_weighted = numerator_weighted
                global_sk_l1 = sk_l1


            d_hat = global_numerator_weighted/((1-sqrt_beta2)*global_sk_l1)
            d = max(d, min(d_hat, d*growth_rate))

        if log_every > 0 and k % log_every == 0:
            logging.info(f"lr: {lr} dlr: {dlr} d_hat: {d_hat}, d: {d}. sk_l1={global_sk_l1:1.1e} numerator_weighted={global_numerator_weighted:1.1e}")

        for group in self.param_groups:
            group['numerator_weighted'] = numerator_weighted
            group['d'] = d

            decay = group['weight_decay']
            k = group['k']
            eps = group['eps']

            for p in group['params']:
                if p.grad is None:
                    continue
                grad = p.grad.data

                state = self.state[p]

                exp_avg, exp_avg_sq = state['exp_avg'], state['exp_avg_sq']

                state['step'] += 1

                denom = exp_avg_sq.sqrt().add_(eps)

                if decay != 0 and decouple:
                    p.data.add_(p.data, alpha=-decay * dlr)

                p.data.addcdiv_(exp_avg, denom, value=-1)

            group['k'] = k + 1

        return loss

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torch.optim import Adam
import numpy as np
import os

class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, 3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, 3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(128 * 4 * 4, 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 100)
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = x.view(-1, 128 * 4 * 4)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = F.relu(self.fc2(x))
        x = self.dropout(x)
        x = self.fc3(x)
        return x

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
train_data = datasets.CIFAR100(root='data', train=True, download=True, transform=transform)
test_data = datasets.CIFAR100(root='data', train=False, download=True, transform=transform)

train_loader = DataLoader(train_data, batch_size=64, shuffle=True)
test_loader = DataLoader(test_data, batch_size=64, shuffle=False)

num_epochs = 175
num_runs = 5
save_every = 10

checkpoint_dir = 'checkpoints'
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

def save_checkpoint(run, epoch, model, optimizer, train_losses, train_accuracies):
    checkpoint = {
        'run': run,
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'train_losses': train_losses,
        'train_accuracies': train_accuracies,
    }
    filename = os.path.join(checkpoint_dir, f'checkpoint_run{run}_epoch{epoch}.pth')
    torch.save(checkpoint, filename)
    print(f'Saved checkpoint: {filename}')

def load_checkpoint(filepath):
    checkpoint = torch.load(filepath)
    return checkpoint['run'], checkpoint['epoch'], checkpoint['model_state_dict'], checkpoint['optimizer_state_dict'], checkpoint['train_losses'], checkpoint['train_accuracies']

all_train_losses = []
all_train_accuracies = []
all_test_accuracies = []

for run in range(num_runs):
    print(f"Starting run {run + 1}/{num_runs}")

    checkpoint_file = os.path.join(checkpoint_dir, f'checkpoint_run{run}_epoch{num_epochs}.pth')
    if os.path.exists(checkpoint_file):
        print(f"Resuming from checkpoint: {checkpoint_file}")
        run, start_epoch, model_state_dict, optimizer_state_dict, train_losses, train_accuracies = load_checkpoint(checkpoint_file)
        model = SimpleCNN().to(device)
        optimizer = DAdaptAdam(model.parameters(), lr=1)
        model.load_state_dict(model_state_dict)
        optimizer.load_state_dict(optimizer_state_dict)
    else:
        start_epoch = 0
        model = SimpleCNN().to(device)
        optimizer = DAdaptAdam(model.parameters(), lr=1)
        train_losses = []
        train_accuracies = []

    for epoch in range(start_epoch, num_epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0
        for i, data in enumerate(train_loader, 0):
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = F.cross_entropy(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        avg_loss = running_loss / len(train_loader)
        train_accuracy = 100 * correct / total

        train_losses.append(avg_loss)
        train_accuracies.append(train_accuracy)

        print(f"Run {run + 1}, Epoch {epoch + 1}, Loss: {avg_loss:.4f}, Training Accuracy: {train_accuracy:.2f}%")

        if (epoch + 1) % save_every == 0:
            save_checkpoint(run, epoch + 1, model, optimizer, train_losses, train_accuracies)

    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for data in test_loader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    test_accuracy = 100 * correct / total
    all_test_accuracies.append(test_accuracy)

    print(f"\nResults after Run {run + 1}:")
    print("Training Losses:", train_losses)
    print("Training Accuracies:", train_accuracies)
    print("Test Accuracy:", test_accuracy)

    save_checkpoint(run, num_epochs, model, optimizer, train_losses, train_accuracies)

    all_train_losses.append(train_losses)
    all_train_accuracies.append(train_accuracies)

np.savetxt('all_train_losses.txt', np.array(all_train_losses), fmt='%f')
np.savetxt('all_train_accuracies.txt', np.array(all_train_accuracies), fmt='%f')
np.savetxt('all_test_accuracies.txt', np.array(all_test_accuracies), fmt='%f')

print("\nAggregated Results:")
print("All Training Losses over Epochs for each run:", all_train_losses)
print("All Training Accuracies over Epochs for each run:", all_train_accuracies)
print("All Test Accuracies for each run:", all_test_accuracies)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to data/cifar-100-python.tar.gz
# 100%|██████████| 169001437/169001437 [00:12<00:00, 14025456.53it/s]
# Extracting data/cifar-100-python.tar.gz to data
# Files already downloaded and verified
# Starting run 1/5
# Run 1, Epoch 1, Loss: 4.2039, Training Accuracy: 4.70%
# Run 1, Epoch 2, Loss: 3.6583, Training Accuracy: 12.36%
# Run 1, Epoch 3, Loss: 3.3401, Training Accuracy: 18.28%
# Run 1, Epoch 4, Loss: 3.1015, Training Accuracy: 22.90%
# Run 1, Epoch 5, Loss: 2.9238, Training Accuracy: 26.33%
# Run 1, Epoch 6, Loss: 2.7818, Training Accuracy: 28.87%
# Run 1, Epoch 7, Loss: 2.6651, Training Accuracy: 31.17%
# Run 1, Epoch 8, Loss: 2.5717, Training Accuracy: 33.12%
# Run 1, Epoch 9, Loss: 2.4905, Training Accuracy: 34.72%
# Run 1, Epoch 10, Loss: 2.4062, Training Accuracy: 36.44%
# Saved checkpoint: checkpoints/checkpoint_run0_epoch10.pth
# Run 1, Epoch 11, Loss: 2.3432, Training Accuracy: 37.83%
# Run 1, Epoch 12, Loss: 2.2876, Training Accuracy: 38.84%
# Run 1, Epoch 13, Loss: 2.2284, Training Accuracy: 40.02%
# Run 1, Epoch 14, Loss: 2.1757, Training Accuracy: 41.12%
# Run 1, Epoch 15, Loss: 2.1295, Training Accuracy: 41.97%
# Run 1, Epoch 16, Loss: 2.0837, Training Accuracy: 43.00%
# Run 1, Epoch 17, Loss: 2.0363, Training Accuracy: 43.96%
# Run 1, Epoch 18, Loss: 1.9893, Training Accuracy: 45.05%
# Run 1, Epoch 19, Loss: 1.9475, Training Accuracy: 46.05%
# Run 1, Epoch 20, Loss: 1.9223, Training Accuracy: 46.26%
# Saved checkpoint: checkpoints/checkpoint_run0_epoch20.pth
# Run 1, Epoch 21, Loss: 1.8793, Training Accuracy: 47.48%
# Run 1, Epoch 22, Loss: 1.8436, Training Accuracy: 48.29%
# Run 1, Epoch 23, Loss: 1.8129, Training Accuracy: 49.09%
# Run 1, Epoch 24, Loss: 1.7908, Training Accuracy: 49.25%
# Run 1, Epoch 25, Loss: 1.7565, Training Accuracy: 50.30%
# Run 1, Epoch 26, Loss: 1.7223, Training Accuracy: 50.77%
# Run 1, Epoch 27, Loss: 1.7012, Training Accuracy: 51.38%
# Run 1, Epoch 28, Loss: 1.6729, Training Accuracy: 52.11%
# Run 1, Epoch 29, Loss: 1.6478, Training Accuracy: 52.70%
# Run 1, Epoch 30, Loss: 1.6250, Training Accuracy: 53.28%
# Saved checkpoint: checkpoints/checkpoint_run0_epoch30.pth
# Run 1, Epoch 31, Loss: 1.6067, Training Accuracy: 53.58%
# Run 1, Epoch 32, Loss: 1.5819, Training Accuracy: 53.95%
# Run 1, Epoch 33, Loss: 1.5653, Training Accuracy: 54.38%
# Run 1, Epoch 34, Loss: 1.5405, Training Accuracy: 55.24%
# Run 1, Epoch 35, Loss: 1.5310, Training Accuracy: 55.50%
# Run 1, Epoch 36, Loss: 1.5026, Training Accuracy: 56.03%
# Run 1, Epoch 37, Loss: 1.4862, Training Accuracy: 56.44%
# Run 1, Epoch 38, Loss: 1.4768, Training Accuracy: 56.71%
# Run 1, Epoch 39, Loss: 1.4637, Training Accuracy: 56.98%
# Run 1, Epoch 40, Loss: 1.4430, Training Accuracy: 57.32%
# Saved checkpoint: checkpoints/checkpoint_run0_epoch40.pth
# Run 1, Epoch 41, Loss: 1.4361, Training Accuracy: 57.98%
# Run 1, Epoch 42, Loss: 1.4037, Training Accuracy: 58.93%
# Run 1, Epoch 43, Loss: 1.3996, Training Accuracy: 58.72%
# Run 1, Epoch 44, Loss: 1.3798, Training Accuracy: 59.42%
# Run 1, Epoch 45, Loss: 1.3703, Training Accuracy: 59.48%
# Run 1, Epoch 46, Loss: 1.3614, Training Accuracy: 59.68%
# Run 1, Epoch 47, Loss: 1.3382, Training Accuracy: 60.08%
# Run 1, Epoch 48, Loss: 1.3211, Training Accuracy: 60.88%
# Run 1, Epoch 49, Loss: 1.3229, Training Accuracy: 60.59%
# Run 1, Epoch 50, Loss: 1.3000, Training Accuracy: 61.24%
# Saved checkpoint: checkpoints/checkpoint_run0_epoch50.pth
# Run 1, Epoch 51, Loss: 1.2973, Training Accuracy: 61.21%
# Run 1, Epoch 52, Loss: 1.2807, Training Accuracy: 61.88%
# Run 1, Epoch 53, Loss: 1.2730, Training Accuracy: 61.95%
# Run 1, Epoch 54, Loss: 1.2670, Training Accuracy: 62.16%
# Run 1, Epoch 55, Loss: 1.2553, Training Accuracy: 62.66%
# Run 1, Epoch 56, Loss: 1.2387, Training Accuracy: 62.85%
# Run 1, Epoch 57, Loss: 1.2490, Training Accuracy: 62.85%
# Run 1, Epoch 58, Loss: 1.2257, Training Accuracy: 63.32%
# Run 1, Epoch 59, Loss: 1.2176, Training Accuracy: 63.59%
# Run 1, Epoch 60, Loss: 1.2010, Training Accuracy: 63.84%
# Saved checkpoint: checkpoints/checkpoint_run0_epoch60.pth
# Run 1, Epoch 61, Loss: 1.2039, Training Accuracy: 64.13%
# Run 1, Epoch 62, Loss: 1.1961, Training Accuracy: 64.10%
# Run 1, Epoch 63, Loss: 1.1797, Training Accuracy: 64.96%
# Run 1, Epoch 64, Loss: 1.1721, Training Accuracy: 64.52%
# Run 1, Epoch 65, Loss: 1.1703, Training Accuracy: 64.73%
# Run 1, Epoch 66, Loss: 1.1745, Training Accuracy: 64.79%
# Run 1, Epoch 67, Loss: 1.1595, Training Accuracy: 65.34%
# Run 1, Epoch 68, Loss: 1.1509, Training Accuracy: 65.74%
# Run 1, Epoch 69, Loss: 1.1338, Training Accuracy: 65.92%
# Run 1, Epoch 70, Loss: 1.1435, Training Accuracy: 65.73%
# Saved checkpoint: checkpoints/checkpoint_run0_epoch70.pth
# Run 1, Epoch 71, Loss: 1.1275, Training Accuracy: 66.06%
# Run 1, Epoch 72, Loss: 1.1214, Training Accuracy: 66.35%
# Run 1, Epoch 73, Loss: 1.1239, Training Accuracy: 66.28%
# Run 1, Epoch 74, Loss: 1.1202, Training Accuracy: 66.56%
# Run 1, Epoch 75, Loss: 1.0999, Training Accuracy: 66.92%
# Run 1, Epoch 76, Loss: 1.0922, Training Accuracy: 67.08%
# Run 1, Epoch 77, Loss: 1.0898, Training Accuracy: 67.02%
# Run 1, Epoch 78, Loss: 1.0753, Training Accuracy: 67.60%
# Run 1, Epoch 79, Loss: 1.0743, Training Accuracy: 67.80%
# Run 1, Epoch 80, Loss: 1.0783, Training Accuracy: 67.49%
# Saved checkpoint: checkpoints/checkpoint_run0_epoch80.pth
# Run 1, Epoch 81, Loss: 1.0690, Training Accuracy: 68.04%
# Run 1, Epoch 82, Loss: 1.0638, Training Accuracy: 68.07%
# Run 1, Epoch 83, Loss: 1.0557, Training Accuracy: 68.31%
# Run 1, Epoch 84, Loss: 1.0414, Training Accuracy: 68.43%
# Run 1, Epoch 85, Loss: 1.0464, Training Accuracy: 68.62%
# Run 1, Epoch 86, Loss: 1.0449, Training Accuracy: 68.61%
# Run 1, Epoch 87, Loss: 1.0391, Training Accuracy: 68.79%
# Run 1, Epoch 88, Loss: 1.0362, Training Accuracy: 68.67%
# Run 1, Epoch 89, Loss: 1.0253, Training Accuracy: 68.87%
# Run 1, Epoch 90, Loss: 1.0211, Training Accuracy: 69.37%
# Saved checkpoint: checkpoints/checkpoint_run0_epoch90.pth
# Run 1, Epoch 91, Loss: 1.0120, Training Accuracy: 69.74%
# Run 1, Epoch 92, Loss: 1.0175, Training Accuracy: 69.35%
# Run 1, Epoch 93, Loss: 0.9966, Training Accuracy: 69.95%
# Run 1, Epoch 94, Loss: 1.0083, Training Accuracy: 69.70%
# Run 1, Epoch 95, Loss: 0.9944, Training Accuracy: 69.90%
# Run 1, Epoch 96, Loss: 0.9974, Training Accuracy: 70.17%
# Run 1, Epoch 97, Loss: 0.9886, Training Accuracy: 70.24%
# Run 1, Epoch 98, Loss: 0.9819, Training Accuracy: 70.60%
# Run 1, Epoch 99, Loss: 0.9865, Training Accuracy: 70.25%
# Run 1, Epoch 100, Loss: 0.9741, Training Accuracy: 70.86%
# Saved checkpoint: checkpoints/checkpoint_run0_epoch100.pth
# Run 1, Epoch 101, Loss: 0.9900, Training Accuracy: 70.29%
# Run 1, Epoch 102, Loss: 0.9781, Training Accuracy: 70.33%
# Run 1, Epoch 103, Loss: 0.9706, Training Accuracy: 70.56%
# Run 1, Epoch 104, Loss: 0.9687, Training Accuracy: 71.00%
# Run 1, Epoch 105, Loss: 0.9717, Training Accuracy: 70.78%
# Run 1, Epoch 106, Loss: 0.9644, Training Accuracy: 71.36%
# Run 1, Epoch 107, Loss: 0.9597, Training Accuracy: 71.08%
# Run 1, Epoch 108, Loss: 0.9479, Training Accuracy: 71.33%
# Run 1, Epoch 109, Loss: 0.9527, Training Accuracy: 71.36%
# Run 1, Epoch 110, Loss: 0.9436, Training Accuracy: 71.40%
# Saved checkpoint: checkpoints/checkpoint_run0_epoch110.pth
# Run 1, Epoch 111, Loss: 0.9506, Training Accuracy: 71.74%
# Run 1, Epoch 112, Loss: 0.9310, Training Accuracy: 71.87%
# Run 1, Epoch 113, Loss: 0.9417, Training Accuracy: 71.85%
# Run 1, Epoch 114, Loss: 0.9253, Training Accuracy: 72.37%
# Run 1, Epoch 115, Loss: 0.9261, Training Accuracy: 72.09%
# Run 1, Epoch 116, Loss: 0.9247, Training Accuracy: 72.23%
# Run 1, Epoch 117, Loss: 0.9159, Training Accuracy: 72.59%
# Run 1, Epoch 118, Loss: 0.9231, Training Accuracy: 72.48%
# Run 1, Epoch 119, Loss: 0.9091, Training Accuracy: 72.82%
# Run 1, Epoch 120, Loss: 0.9118, Training Accuracy: 72.61%
# Saved checkpoint: checkpoints/checkpoint_run0_epoch120.pth
# Run 1, Epoch 121, Loss: 0.9180, Training Accuracy: 72.54%
# Run 1, Epoch 122, Loss: 0.9149, Training Accuracy: 72.83%
# Run 1, Epoch 123, Loss: 0.9034, Training Accuracy: 72.92%
# Run 1, Epoch 124, Loss: 0.9101, Training Accuracy: 72.86%
# Run 1, Epoch 125, Loss: 0.9014, Training Accuracy: 73.12%
# Run 1, Epoch 126, Loss: 0.9056, Training Accuracy: 72.83%
# Run 1, Epoch 127, Loss: 0.8945, Training Accuracy: 73.30%
# Run 1, Epoch 128, Loss: 0.8750, Training Accuracy: 73.64%
# Run 1, Epoch 129, Loss: 0.8955, Training Accuracy: 73.25%
# Run 1, Epoch 130, Loss: 0.8882, Training Accuracy: 73.62%
# Saved checkpoint: checkpoints/checkpoint_run0_epoch130.pth
# Run 1, Epoch 131, Loss: 0.9004, Training Accuracy: 72.99%
# Run 1, Epoch 132, Loss: 0.8759, Training Accuracy: 73.72%
# Run 1, Epoch 133, Loss: 0.8850, Training Accuracy: 73.63%
# Run 1, Epoch 134, Loss: 0.8811, Training Accuracy: 73.62%
# Run 1, Epoch 135, Loss: 0.8749, Training Accuracy: 73.84%
# Run 1, Epoch 136, Loss: 0.8873, Training Accuracy: 73.60%
# Run 1, Epoch 137, Loss: 0.8636, Training Accuracy: 74.01%
# Run 1, Epoch 138, Loss: 0.8732, Training Accuracy: 74.04%
# Run 1, Epoch 139, Loss: 0.8754, Training Accuracy: 73.89%
# Run 1, Epoch 140, Loss: 0.8689, Training Accuracy: 74.11%
# Saved checkpoint: checkpoints/checkpoint_run0_epoch140.pth
# Run 1, Epoch 141, Loss: 0.8549, Training Accuracy: 74.40%
# Run 1, Epoch 142, Loss: 0.8684, Training Accuracy: 74.02%
# Run 1, Epoch 143, Loss: 0.8662, Training Accuracy: 74.00%
# Run 1, Epoch 144, Loss: 0.8595, Training Accuracy: 74.26%
# Run 1, Epoch 145, Loss: 0.8599, Training Accuracy: 74.48%
# Run 1, Epoch 146, Loss: 0.8593, Training Accuracy: 74.39%
# Run 1, Epoch 147, Loss: 0.8529, Training Accuracy: 74.40%
# Run 1, Epoch 148, Loss: 0.8486, Training Accuracy: 74.58%
# Run 1, Epoch 149, Loss: 0.8493, Training Accuracy: 74.80%
# Run 1, Epoch 150, Loss: 0.8630, Training Accuracy: 74.49%
# Saved checkpoint: checkpoints/checkpoint_run0_epoch150.pth
# Run 1, Epoch 151, Loss: 0.8503, Training Accuracy: 74.56%
# Run 1, Epoch 152, Loss: 0.8415, Training Accuracy: 74.76%
# Run 1, Epoch 153, Loss: 0.8386, Training Accuracy: 75.12%
# Run 1, Epoch 154, Loss: 0.8484, Training Accuracy: 74.65%
# Run 1, Epoch 155, Loss: 0.8347, Training Accuracy: 75.15%
# Run 1, Epoch 156, Loss: 0.8336, Training Accuracy: 74.93%
# Run 1, Epoch 157, Loss: 0.8260, Training Accuracy: 75.37%
# Run 1, Epoch 158, Loss: 0.8355, Training Accuracy: 75.15%
# Run 1, Epoch 159, Loss: 0.8225, Training Accuracy: 75.21%
# Run 1, Epoch 160, Loss: 0.8094, Training Accuracy: 75.89%
# Saved checkpoint: checkpoints/checkpoint_run0_epoch160.pth
# Run 1, Epoch 161, Loss: 0.8320, Training Accuracy: 75.23%
# Run 1, Epoch 162, Loss: 0.8278, Training Accuracy: 75.37%
# Run 1, Epoch 163, Loss: 0.8144, Training Accuracy: 75.65%
# Run 1, Epoch 164, Loss: 0.8232, Training Accuracy: 75.46%
# Run 1, Epoch 165, Loss: 0.8301, Training Accuracy: 75.26%
# Run 1, Epoch 166, Loss: 0.8055, Training Accuracy: 75.89%
# Run 1, Epoch 167, Loss: 0.8249, Training Accuracy: 75.44%
# Run 1, Epoch 168, Loss: 0.8274, Training Accuracy: 75.29%
# Run 1, Epoch 169, Loss: 0.8114, Training Accuracy: 75.74%
# Run 1, Epoch 170, Loss: 0.8220, Training Accuracy: 75.49%
# Saved checkpoint: checkpoints/checkpoint_run0_epoch170.pth
# Run 1, Epoch 171, Loss: 0.8059, Training Accuracy: 76.00%
# Run 1, Epoch 172, Loss: 0.8096, Training Accuracy: 75.75%
# Run 1, Epoch 173, Loss: 0.8126, Training Accuracy: 75.74%
# Run 1, Epoch 174, Loss: 0.8252, Training Accuracy: 75.43%
# Run 1, Epoch 175, Loss: 0.8161, Training Accuracy: 75.75%
#
# Results after Run 1:
# Training Losses: [4.203888251653413, 3.6582889038583506, 3.340076491655901, 3.1014670618354816, 2.9237968632022437, 2.7818099836559247, 2.66510353140209, 2.5716895973286054, 2.490488011361388, 2.4062194033047124, 2.3431669837983367, 2.287645283257565, 2.2283681833835516, 2.1756959363932498, 2.1294573676555664, 2.0836770847020554, 2.036349105560566, 1.9892777770071688, 1.947455859855008, 1.9222807891838385, 1.8792649217883644, 1.8435723659632457, 1.8129329221023014, 1.7908228155597092, 1.7565203377657839, 1.7222915695756293, 1.7011629989384995, 1.6729237452492385, 1.6478395818749352, 1.6249655533934493, 1.6067317666300118, 1.5818654557932978, 1.565262724828842, 1.5404537892555032, 1.5309691897133733, 1.5026089513240872, 1.4861673921575327, 1.4768416170421463, 1.4637135317563401, 1.442989640376147, 1.4360964478129317, 1.403719976430049, 1.399599027831841, 1.3797600673287727, 1.3702953491369476, 1.3613833931400954, 1.3382222355936495, 1.32108175053316, 1.322940992805964, 1.3000147345730715, 1.2973013409720662, 1.2806803143542747, 1.2729567151392818, 1.266950386945549, 1.2553403781503059, 1.2387471295836028, 1.2490497243678784, 1.225728289474307, 1.217567236069828, 1.2010321802342945, 1.2038687046836405, 1.1960763964811554, 1.179650199763915, 1.172143597051006, 1.1703065598712248, 1.1745002424473043, 1.159511187573528, 1.1509087873846673, 1.133820419878606, 1.1435450404653769, 1.1274999958627365, 1.1213686803875067, 1.1239473630705148, 1.1202302501939447, 1.0998643659569722, 1.0921545506590773, 1.0897732335893089, 1.0753244254595178, 1.0743350864523817, 1.0782766072341547, 1.068977935539792, 1.0637686053657776, 1.0556567759465074, 1.0413691343553841, 1.0463928503301136, 1.0448997975005518, 1.0390973492808964, 1.0362272089552087, 1.0252894990508208, 1.0210987092436428, 1.011993800663887, 1.0175323583890714, 0.9965898656784116, 1.0082526717649396, 0.9944273207498633, 0.9974011846286867, 0.988609178672971, 0.9818832355234629, 0.9865243742075722, 0.9741017857704626, 0.9900044513023113, 0.9780511750513331, 0.9706224089540789, 0.9687080399307144, 0.9716742153057967, 0.9644475603271323, 0.9596697891993291, 0.947945238341151, 0.952652898400336, 0.9436307621505254, 0.9505757448999473, 0.9310110425552749, 0.9416782279377398, 0.9252684109122552, 0.926055316463151, 0.9246938287297173, 0.915854129454364, 0.9230538830732751, 0.9091273489053292, 0.9118457104620117, 0.9179756395957049, 0.9148939197020762, 0.9034031592595303, 0.910131547762, 0.9014445741082091, 0.9055826096888393, 0.8945445401208175, 0.8750458866586466, 0.8954681020106197, 0.8882468351546455, 0.900388492723865, 0.8759331947473614, 0.8850257601350775, 0.881149038748668, 0.8748573307948344, 0.8872953501275128, 0.8635743368236001, 0.8731931705227898, 0.8754017586293428, 0.868926738610353, 0.8549037909187625, 0.8684133838128556, 0.8662306663325375, 0.8594600402409464, 0.8598550384306847, 0.8593413396869474, 0.8528633156548375, 0.8486226473546699, 0.8493452645704874, 0.8629924129799503, 0.8503157185471576, 0.8415090221806866, 0.8385976123840303, 0.8484127719307799, 0.8347056949382547, 0.8336256316403294, 0.8260075416406403, 0.8354918255144373, 0.8224897067946242, 0.8093598551305053, 0.8319833944063357, 0.827760191029295, 0.814402061121543, 0.8231647799310782, 0.8300954650353898, 0.8054535742992025, 0.824886218208791, 0.8274445902279881, 0.8113518724661044, 0.8220428979534018, 0.8058665263302186, 0.8096291986496552, 0.8126240519382765, 0.825190314399007, 0.8161208171140203]
# Training Accuracies: [4.702, 12.356, 18.276, 22.898, 26.334, 28.87, 31.174, 33.118, 34.722, 36.44, 37.83, 38.842, 40.016, 41.118, 41.97, 43.002, 43.96, 45.048, 46.05, 46.258, 47.478, 48.29, 49.086, 49.248, 50.3, 50.766, 51.378, 52.11, 52.698, 53.282, 53.576, 53.952, 54.384, 55.24, 55.504, 56.034, 56.438, 56.708, 56.978, 57.322, 57.976, 58.934, 58.72, 59.424, 59.484, 59.68, 60.076, 60.876, 60.594, 61.238, 61.208, 61.878, 61.95, 62.16, 62.656, 62.85, 62.848, 63.318, 63.592, 63.842, 64.128, 64.102, 64.96, 64.524, 64.73, 64.792, 65.338, 65.736, 65.918, 65.728, 66.056, 66.352, 66.284, 66.562, 66.922, 67.082, 67.016, 67.604, 67.8, 67.488, 68.042, 68.07, 68.31, 68.432, 68.622, 68.61, 68.786, 68.672, 68.868, 69.366, 69.738, 69.346, 69.952, 69.702, 69.902, 70.166, 70.24, 70.602, 70.254, 70.86, 70.294, 70.334, 70.56, 71.0, 70.784, 71.364, 71.08, 71.326, 71.358, 71.404, 71.744, 71.874, 71.854, 72.374, 72.094, 72.232, 72.592, 72.482, 72.822, 72.612, 72.54, 72.834, 72.924, 72.86, 73.124, 72.832, 73.302, 73.64, 73.248, 73.622, 72.99, 73.722, 73.634, 73.618, 73.842, 73.598, 74.014, 74.042, 73.89, 74.108, 74.404, 74.018, 73.996, 74.264, 74.476, 74.388, 74.402, 74.578, 74.798, 74.49, 74.558, 74.756, 75.122, 74.654, 75.148, 74.932, 75.374, 75.15, 75.208, 75.892, 75.234, 75.368, 75.646, 75.462, 75.256, 75.894, 75.436, 75.29, 75.736, 75.486, 75.998, 75.75, 75.738, 75.428, 75.752]
# Test Accuracy: 40.13
# Saved checkpoint: checkpoints/checkpoint_run0_epoch175.pth
# Starting run 2/5
# Run 2, Epoch 1, Loss: 4.1775, Training Accuracy: 5.18%
# Run 2, Epoch 2, Loss: 3.6493, Training Accuracy: 12.40%
# Run 2, Epoch 3, Loss: 3.3430, Training Accuracy: 18.16%
# Run 2, Epoch 4, Loss: 3.1341, Training Accuracy: 21.89%
# Run 2, Epoch 5, Loss: 2.9724, Training Accuracy: 24.86%
# Run 2, Epoch 6, Loss: 2.8414, Training Accuracy: 27.60%
# Run 2, Epoch 7, Loss: 2.7253, Training Accuracy: 29.61%
# Run 2, Epoch 8, Loss: 2.6186, Training Accuracy: 31.82%
# Run 2, Epoch 9, Loss: 2.5424, Training Accuracy: 33.61%
# Run 2, Epoch 10, Loss: 2.4593, Training Accuracy: 35.50%
# Saved checkpoint: checkpoints/checkpoint_run1_epoch10.pth
# Run 2, Epoch 11, Loss: 2.3878, Training Accuracy: 36.90%
# Run 2, Epoch 12, Loss: 2.3214, Training Accuracy: 38.26%
# Run 2, Epoch 13, Loss: 2.2541, Training Accuracy: 39.56%
# Run 2, Epoch 14, Loss: 2.1885, Training Accuracy: 40.96%
# Run 2, Epoch 15, Loss: 2.1332, Training Accuracy: 42.17%
# Run 2, Epoch 16, Loss: 2.0781, Training Accuracy: 43.21%
# Run 2, Epoch 17, Loss: 2.0305, Training Accuracy: 44.01%
# Run 2, Epoch 18, Loss: 1.9842, Training Accuracy: 45.05%
# Run 2, Epoch 19, Loss: 1.9426, Training Accuracy: 46.12%
# Run 2, Epoch 20, Loss: 1.8927, Training Accuracy: 47.22%
# Saved checkpoint: checkpoints/checkpoint_run1_epoch20.pth
# Run 2, Epoch 21, Loss: 1.8464, Training Accuracy: 48.29%
# Run 2, Epoch 22, Loss: 1.8017, Training Accuracy: 49.11%
# Run 2, Epoch 23, Loss: 1.7706, Training Accuracy: 49.83%
# Run 2, Epoch 24, Loss: 1.7207, Training Accuracy: 50.84%
# Run 2, Epoch 25, Loss: 1.6858, Training Accuracy: 51.72%
# Run 2, Epoch 26, Loss: 1.6519, Training Accuracy: 52.46%
# Run 2, Epoch 27, Loss: 1.6100, Training Accuracy: 53.33%
# Run 2, Epoch 28, Loss: 1.5786, Training Accuracy: 54.06%
# Run 2, Epoch 29, Loss: 1.5498, Training Accuracy: 54.85%
# Run 2, Epoch 30, Loss: 1.5205, Training Accuracy: 55.56%
# Saved checkpoint: checkpoints/checkpoint_run1_epoch30.pth
# Run 2, Epoch 31, Loss: 1.4925, Training Accuracy: 56.20%
# Run 2, Epoch 32, Loss: 1.4535, Training Accuracy: 57.00%
# Run 2, Epoch 33, Loss: 1.4266, Training Accuracy: 57.81%
# Run 2, Epoch 34, Loss: 1.4045, Training Accuracy: 58.42%
# Run 2, Epoch 35, Loss: 1.3769, Training Accuracy: 58.91%
# Run 2, Epoch 36, Loss: 1.3517, Training Accuracy: 59.83%
# Run 2, Epoch 37, Loss: 1.3376, Training Accuracy: 59.87%
# Run 2, Epoch 38, Loss: 1.2971, Training Accuracy: 60.98%
# Run 2, Epoch 39, Loss: 1.2807, Training Accuracy: 61.48%
# Run 2, Epoch 40, Loss: 1.2549, Training Accuracy: 62.11%
# Saved checkpoint: checkpoints/checkpoint_run1_epoch40.pth
# Run 2, Epoch 41, Loss: 1.2347, Training Accuracy: 62.73%
# Run 2, Epoch 42, Loss: 1.2298, Training Accuracy: 62.75%
# Run 2, Epoch 43, Loss: 1.2048, Training Accuracy: 63.33%
# Run 2, Epoch 44, Loss: 1.1820, Training Accuracy: 64.08%
# Run 2, Epoch 45, Loss: 1.1618, Training Accuracy: 64.58%
# Run 2, Epoch 46, Loss: 1.1429, Training Accuracy: 65.10%
# Run 2, Epoch 47, Loss: 1.1376, Training Accuracy: 65.38%
# Run 2, Epoch 48, Loss: 1.1151, Training Accuracy: 65.68%
# Run 2, Epoch 49, Loss: 1.1031, Training Accuracy: 66.31%
# Run 2, Epoch 50, Loss: 1.0822, Training Accuracy: 66.82%
# Saved checkpoint: checkpoints/checkpoint_run1_epoch50.pth
# Run 2, Epoch 51, Loss: 1.0741, Training Accuracy: 67.10%
# Run 2, Epoch 52, Loss: 1.0587, Training Accuracy: 67.34%
# Run 2, Epoch 53, Loss: 1.0478, Training Accuracy: 67.62%
# Run 2, Epoch 54, Loss: 1.0275, Training Accuracy: 68.16%
# Run 2, Epoch 55, Loss: 1.0219, Training Accuracy: 68.36%
# Run 2, Epoch 56, Loss: 1.0020, Training Accuracy: 68.86%
# Run 2, Epoch 57, Loss: 1.0063, Training Accuracy: 68.88%
# Run 2, Epoch 58, Loss: 0.9929, Training Accuracy: 69.15%
# Run 2, Epoch 59, Loss: 0.9723, Training Accuracy: 69.72%
# Run 2, Epoch 60, Loss: 0.9706, Training Accuracy: 69.76%
# Saved checkpoint: checkpoints/checkpoint_run1_epoch60.pth
# Run 2, Epoch 61, Loss: 0.9584, Training Accuracy: 70.32%
# Run 2, Epoch 62, Loss: 0.9522, Training Accuracy: 70.57%
# Run 2, Epoch 63, Loss: 0.9318, Training Accuracy: 70.87%
# Run 2, Epoch 64, Loss: 0.9324, Training Accuracy: 71.33%
# Run 2, Epoch 65, Loss: 0.9241, Training Accuracy: 71.35%
# Run 2, Epoch 66, Loss: 0.9184, Training Accuracy: 71.61%
# Run 2, Epoch 67, Loss: 0.9068, Training Accuracy: 71.77%
# Run 2, Epoch 68, Loss: 0.9060, Training Accuracy: 71.90%
# Run 2, Epoch 69, Loss: 0.8933, Training Accuracy: 72.08%
# Run 2, Epoch 70, Loss: 0.8787, Training Accuracy: 72.59%
# Saved checkpoint: checkpoints/checkpoint_run1_epoch70.pth
# Run 2, Epoch 71, Loss: 0.8761, Training Accuracy: 72.94%
# Run 2, Epoch 72, Loss: 0.8694, Training Accuracy: 73.16%
# Run 2, Epoch 73, Loss: 0.8532, Training Accuracy: 73.34%
# Run 2, Epoch 74, Loss: 0.8519, Training Accuracy: 73.43%
# Run 2, Epoch 75, Loss: 0.8447, Training Accuracy: 73.83%
# Run 2, Epoch 76, Loss: 0.8412, Training Accuracy: 73.82%
# Run 2, Epoch 77, Loss: 0.8422, Training Accuracy: 73.72%
# Run 2, Epoch 78, Loss: 0.8331, Training Accuracy: 73.98%
# Run 2, Epoch 79, Loss: 0.8242, Training Accuracy: 74.27%
# Run 2, Epoch 80, Loss: 0.8228, Training Accuracy: 74.30%
# Saved checkpoint: checkpoints/checkpoint_run1_epoch80.pth
# Run 2, Epoch 81, Loss: 0.8115, Training Accuracy: 74.48%
# Run 2, Epoch 82, Loss: 0.8033, Training Accuracy: 75.02%
# Run 2, Epoch 83, Loss: 0.7974, Training Accuracy: 75.04%
# Run 2, Epoch 84, Loss: 0.7956, Training Accuracy: 75.29%
# Run 2, Epoch 85, Loss: 0.7934, Training Accuracy: 75.37%
# Run 2, Epoch 86, Loss: 0.7860, Training Accuracy: 75.34%
# Run 2, Epoch 87, Loss: 0.7780, Training Accuracy: 75.46%
# Run 2, Epoch 88, Loss: 0.7611, Training Accuracy: 76.08%
# Run 2, Epoch 89, Loss: 0.7747, Training Accuracy: 75.83%
# Run 2, Epoch 90, Loss: 0.7674, Training Accuracy: 75.89%
# Saved checkpoint: checkpoints/checkpoint_run1_epoch90.pth
# Run 2, Epoch 91, Loss: 0.7548, Training Accuracy: 76.66%
# Run 2, Epoch 92, Loss: 0.7634, Training Accuracy: 76.32%
# Run 2, Epoch 93, Loss: 0.7439, Training Accuracy: 76.61%
# Run 2, Epoch 94, Loss: 0.7399, Training Accuracy: 76.78%
# Run 2, Epoch 95, Loss: 0.7469, Training Accuracy: 76.72%
# Run 2, Epoch 96, Loss: 0.7344, Training Accuracy: 76.99%
# Run 2, Epoch 97, Loss: 0.7339, Training Accuracy: 77.20%
# Run 2, Epoch 98, Loss: 0.7287, Training Accuracy: 77.21%
# Run 2, Epoch 99, Loss: 0.7254, Training Accuracy: 77.46%
# Run 2, Epoch 100, Loss: 0.7237, Training Accuracy: 77.57%
# Saved checkpoint: checkpoints/checkpoint_run1_epoch100.pth
# Run 2, Epoch 101, Loss: 0.7194, Training Accuracy: 77.67%
# Run 2, Epoch 102, Loss: 0.7226, Training Accuracy: 77.52%
# Run 2, Epoch 103, Loss: 0.7135, Training Accuracy: 77.83%
# Run 2, Epoch 104, Loss: 0.7163, Training Accuracy: 77.88%
# Run 2, Epoch 105, Loss: 0.6995, Training Accuracy: 78.20%
# Run 2, Epoch 106, Loss: 0.7066, Training Accuracy: 78.36%
# Run 2, Epoch 107, Loss: 0.6942, Training Accuracy: 78.34%
# Run 2, Epoch 108, Loss: 0.7023, Training Accuracy: 78.25%
# Run 2, Epoch 109, Loss: 0.6894, Training Accuracy: 78.53%
# Run 2, Epoch 110, Loss: 0.6831, Training Accuracy: 78.89%
# Saved checkpoint: checkpoints/checkpoint_run1_epoch110.pth
# Run 2, Epoch 111, Loss: 0.6889, Training Accuracy: 78.72%
# Run 2, Epoch 112, Loss: 0.6873, Training Accuracy: 78.69%
# Run 2, Epoch 113, Loss: 0.6793, Training Accuracy: 78.83%
# Run 2, Epoch 114, Loss: 0.6766, Training Accuracy: 78.94%
# Run 2, Epoch 115, Loss: 0.6723, Training Accuracy: 79.17%
# Run 2, Epoch 116, Loss: 0.6770, Training Accuracy: 79.02%
# Run 2, Epoch 117, Loss: 0.6587, Training Accuracy: 79.64%
# Run 2, Epoch 118, Loss: 0.6565, Training Accuracy: 79.65%
# Run 2, Epoch 119, Loss: 0.6714, Training Accuracy: 79.27%
# Run 2, Epoch 120, Loss: 0.6640, Training Accuracy: 79.48%
# Saved checkpoint: checkpoints/checkpoint_run1_epoch120.pth
# Run 2, Epoch 121, Loss: 0.6542, Training Accuracy: 79.81%
# Run 2, Epoch 122, Loss: 0.6466, Training Accuracy: 79.82%
# Run 2, Epoch 123, Loss: 0.6539, Training Accuracy: 79.86%
# Run 2, Epoch 124, Loss: 0.6447, Training Accuracy: 79.83%
# Run 2, Epoch 125, Loss: 0.6452, Training Accuracy: 80.12%
# Run 2, Epoch 126, Loss: 0.6507, Training Accuracy: 79.72%
# Run 2, Epoch 127, Loss: 0.6452, Training Accuracy: 79.94%
# Run 2, Epoch 128, Loss: 0.6333, Training Accuracy: 80.40%
# Run 2, Epoch 129, Loss: 0.6276, Training Accuracy: 80.50%
# Run 2, Epoch 130, Loss: 0.6367, Training Accuracy: 80.20%
# Saved checkpoint: checkpoints/checkpoint_run1_epoch130.pth
# Run 2, Epoch 131, Loss: 0.6239, Training Accuracy: 80.49%
# Run 2, Epoch 132, Loss: 0.6289, Training Accuracy: 80.48%
# Run 2, Epoch 133, Loss: 0.6334, Training Accuracy: 80.01%
# Run 2, Epoch 134, Loss: 0.6218, Training Accuracy: 80.64%
# Run 2, Epoch 135, Loss: 0.6196, Training Accuracy: 81.06%
# Run 2, Epoch 136, Loss: 0.6208, Training Accuracy: 80.66%
# Run 2, Epoch 137, Loss: 0.6195, Training Accuracy: 81.08%
# Run 2, Epoch 138, Loss: 0.6218, Training Accuracy: 80.64%
# Run 2, Epoch 139, Loss: 0.6118, Training Accuracy: 81.08%
# Run 2, Epoch 140, Loss: 0.5989, Training Accuracy: 81.49%
# Saved checkpoint: checkpoints/checkpoint_run1_epoch140.pth
# Run 2, Epoch 141, Loss: 0.6227, Training Accuracy: 80.55%
# Run 2, Epoch 142, Loss: 0.6083, Training Accuracy: 81.38%
# Run 2, Epoch 143, Loss: 0.6135, Training Accuracy: 80.83%
# Run 2, Epoch 144, Loss: 0.5964, Training Accuracy: 81.48%
# Run 2, Epoch 145, Loss: 0.6124, Training Accuracy: 81.00%
# Run 2, Epoch 146, Loss: 0.5982, Training Accuracy: 81.44%
# Run 2, Epoch 147, Loss: 0.5932, Training Accuracy: 81.67%
# Run 2, Epoch 148, Loss: 0.5949, Training Accuracy: 81.82%
# Run 2, Epoch 149, Loss: 0.5978, Training Accuracy: 81.65%
# Run 2, Epoch 150, Loss: 0.5996, Training Accuracy: 81.49%
# Saved checkpoint: checkpoints/checkpoint_run1_epoch150.pth
# Run 2, Epoch 151, Loss: 0.6026, Training Accuracy: 81.27%
# Run 2, Epoch 152, Loss: 0.5884, Training Accuracy: 81.71%
# Run 2, Epoch 153, Loss: 0.5894, Training Accuracy: 81.69%
# Run 2, Epoch 154, Loss: 0.5900, Training Accuracy: 81.72%
# Run 2, Epoch 155, Loss: 0.5933, Training Accuracy: 81.72%
# Run 2, Epoch 156, Loss: 0.5838, Training Accuracy: 82.07%
# Run 2, Epoch 157, Loss: 0.5900, Training Accuracy: 81.74%
# Run 2, Epoch 158, Loss: 0.5748, Training Accuracy: 82.27%
# Run 2, Epoch 159, Loss: 0.5759, Training Accuracy: 82.43%
# Run 2, Epoch 160, Loss: 0.5799, Training Accuracy: 82.35%
# Saved checkpoint: checkpoints/checkpoint_run1_epoch160.pth
# Run 2, Epoch 161, Loss: 0.5819, Training Accuracy: 82.10%
# Run 2, Epoch 162, Loss: 0.5685, Training Accuracy: 82.61%
# Run 2, Epoch 163, Loss: 0.5882, Training Accuracy: 82.01%
# Run 2, Epoch 164, Loss: 0.5730, Training Accuracy: 82.38%
# Run 2, Epoch 165, Loss: 0.5638, Training Accuracy: 82.76%
# Run 2, Epoch 166, Loss: 0.5784, Training Accuracy: 82.18%
# Run 2, Epoch 167, Loss: 0.5621, Training Accuracy: 82.54%
# Run 2, Epoch 168, Loss: 0.5771, Training Accuracy: 82.23%
# Run 2, Epoch 169, Loss: 0.5633, Training Accuracy: 82.71%
# Run 2, Epoch 170, Loss: 0.5720, Training Accuracy: 82.44%
# Saved checkpoint: checkpoints/checkpoint_run1_epoch170.pth
# Run 2, Epoch 171, Loss: 0.5599, Training Accuracy: 82.58%
# Run 2, Epoch 172, Loss: 0.5575, Training Accuracy: 82.87%
# Run 2, Epoch 173, Loss: 0.5586, Training Accuracy: 82.75%
# Run 2, Epoch 174, Loss: 0.5596, Training Accuracy: 82.83%
# Run 2, Epoch 175, Loss: 0.5555, Training Accuracy: 82.84%
#
# Results after Run 2:
# Training Losses: [4.177533014351145, 3.6492984581481465, 3.343029891133613, 3.134077124278564, 2.9724115044869426, 2.8413528493603173, 2.725267259361189, 2.618562412993682, 2.5423795335433064, 2.459252940266943, 2.3877767623233064, 2.3214120837428687, 2.254122733764941, 2.1884908979506137, 2.1332187433072063, 2.0781021952019323, 2.0304729284532845, 1.9841869691448748, 1.94262206569657, 1.8927319679418793, 1.8463989985568443, 1.8016761431608663, 1.7705969824205579, 1.7207213051788641, 1.6858401612552536, 1.6518525860803512, 1.6100195958791181, 1.57859812619741, 1.549797983882982, 1.5204748422136087, 1.4925295706752622, 1.453499428299077, 1.4266193174492672, 1.4044812125775514, 1.376897642831973, 1.3516942127738767, 1.3376026190150425, 1.2970854610280917, 1.2807002528701596, 1.2548820634022393, 1.2347486657102396, 1.2297977515498695, 1.2048228587335943, 1.1819531108869616, 1.1618311768754974, 1.142923412649223, 1.1376027128733028, 1.1151332365125037, 1.103142587920589, 1.0821682098119154, 1.074123774800459, 1.058652285953312, 1.0477743506279138, 1.0274844822828726, 1.021936604510183, 1.0019619671432562, 1.006346880322527, 0.9929282935836431, 0.9722554839937888, 0.9706155355171779, 0.9583502689667065, 0.9522322673550652, 0.9318151344423709, 0.9323800360912557, 0.9241389657758996, 0.9184459349154817, 0.9068151596562027, 0.9060187785674239, 0.8933429191332034, 0.8787303290632374, 0.8760887610028162, 0.8694171609780977, 0.8532487860573527, 0.8518933237284956, 0.8446899949360991, 0.8412184458025886, 0.8422366767130849, 0.8331183344887956, 0.8242246402270349, 0.8227856319654933, 0.8114800324372928, 0.8033294384284397, 0.7973565346444659, 0.7956427296485438, 0.7934159526739584, 0.786037747398057, 0.77803470613554, 0.7611135335072227, 0.7747063470999603, 0.7674265160127673, 0.7548228089538072, 0.7633956133404656, 0.7438889357363782, 0.7399209579619606, 0.7469466545469011, 0.734404108217915, 0.7339112594380708, 0.728737168261767, 0.725448961186287, 0.7236837078924374, 0.7194153249187543, 0.7225826242009697, 0.713495613897548, 0.7162790437564825, 0.699541709840755, 0.7066251521601397, 0.6941586011434759, 0.7023356468095194, 0.6894289698747113, 0.6830811124399799, 0.688894007821827, 0.6872767869316404, 0.6792504043149217, 0.6766460042475434, 0.6722860906053992, 0.6770113956592881, 0.6587457357312713, 0.6565113465880494, 0.6714122623891172, 0.6640059525323341, 0.6541852039449355, 0.6465581053739313, 0.6538543090262376, 0.6446520151841976, 0.6452485846207879, 0.6506557166766938, 0.6451620570457804, 0.6333123033537584, 0.6276324635843182, 0.6366717295573495, 0.623913989728674, 0.6288737347897362, 0.6333737116869148, 0.6217796193135668, 0.6195896943588086, 0.6208034290377137, 0.6195461773468406, 0.6217502683134335, 0.6117624767562923, 0.5988665468552533, 0.6226582594997133, 0.6083468014321973, 0.6134800442573055, 0.5963728047354752, 0.612447925121583, 0.5982407054213612, 0.5931954302674974, 0.5949146088279421, 0.5978137987196598, 0.5995862440341879, 0.6025814941091001, 0.5884346112494578, 0.5893961728724373, 0.5900202740907974, 0.5933228366820099, 0.5837545674818251, 0.5900349232661145, 0.5748295539518451, 0.5759414409280128, 0.5799437302267155, 0.5818785460060819, 0.568480303925474, 0.5882303881866243, 0.5730089902725366, 0.5637691934471545, 0.578384104877939, 0.5621210355549822, 0.5770619480925447, 0.5632863302174431, 0.5720492334812498, 0.5598883875228865, 0.5574793851436557, 0.5585992638107455, 0.5596394042110504, 0.5554524717466606]
# Training Accuracies: [5.176, 12.402, 18.162, 21.892, 24.858, 27.596, 29.606, 31.82, 33.608, 35.502, 36.896, 38.262, 39.564, 40.96, 42.168, 43.206, 44.006, 45.048, 46.124, 47.222, 48.292, 49.106, 49.826, 50.836, 51.722, 52.462, 53.326, 54.058, 54.846, 55.562, 56.196, 57.004, 57.81, 58.422, 58.91, 59.826, 59.874, 60.984, 61.478, 62.112, 62.728, 62.754, 63.328, 64.076, 64.578, 65.104, 65.382, 65.676, 66.308, 66.818, 67.102, 67.342, 67.62, 68.158, 68.356, 68.864, 68.876, 69.154, 69.718, 69.762, 70.32, 70.57, 70.87, 71.334, 71.346, 71.608, 71.768, 71.9, 72.084, 72.588, 72.942, 73.162, 73.338, 73.426, 73.83, 73.82, 73.72, 73.976, 74.272, 74.302, 74.478, 75.02, 75.04, 75.294, 75.374, 75.342, 75.46, 76.082, 75.826, 75.89, 76.658, 76.324, 76.61, 76.78, 76.724, 76.99, 77.204, 77.21, 77.464, 77.574, 77.666, 77.52, 77.826, 77.88, 78.202, 78.358, 78.344, 78.252, 78.528, 78.892, 78.722, 78.694, 78.832, 78.938, 79.172, 79.024, 79.644, 79.646, 79.272, 79.478, 79.808, 79.822, 79.86, 79.826, 80.122, 79.724, 79.938, 80.398, 80.502, 80.204, 80.492, 80.482, 80.008, 80.644, 81.056, 80.658, 81.076, 80.636, 81.084, 81.488, 80.552, 81.38, 80.83, 81.476, 81.0, 81.442, 81.666, 81.818, 81.65, 81.494, 81.272, 81.712, 81.686, 81.722, 81.722, 82.07, 81.736, 82.268, 82.43, 82.352, 82.096, 82.608, 82.012, 82.378, 82.764, 82.176, 82.54, 82.232, 82.71, 82.44, 82.582, 82.866, 82.746, 82.826, 82.836]
# Test Accuracy: 42.83
# Saved checkpoint: checkpoints/checkpoint_run1_epoch175.pth
# Starting run 3/5
# Run 3, Epoch 1, Loss: 4.2056, Training Accuracy: 4.75%
# Run 3, Epoch 2, Loss: 3.6333, Training Accuracy: 12.51%
# Run 3, Epoch 3, Loss: 3.3273, Training Accuracy: 18.21%
# Run 3, Epoch 4, Loss: 3.1151, Training Accuracy: 22.28%
# Run 3, Epoch 5, Loss: 2.9503, Training Accuracy: 25.10%
# Run 3, Epoch 6, Loss: 2.8098, Training Accuracy: 28.24%
# Run 3, Epoch 7, Loss: 2.6935, Training Accuracy: 30.43%
# Run 3, Epoch 8, Loss: 2.5850, Training Accuracy: 32.94%
# Run 3, Epoch 9, Loss: 2.4975, Training Accuracy: 34.54%
# Run 3, Epoch 10, Loss: 2.4055, Training Accuracy: 36.29%
# Saved checkpoint: checkpoints/checkpoint_run2_epoch10.pth
# Run 3, Epoch 11, Loss: 2.3262, Training Accuracy: 38.17%
# Run 3, Epoch 12, Loss: 2.2596, Training Accuracy: 39.52%
# Run 3, Epoch 13, Loss: 2.1811, Training Accuracy: 40.87%
# Run 3, Epoch 14, Loss: 2.1270, Training Accuracy: 42.11%
# Run 3, Epoch 15, Loss: 2.0603, Training Accuracy: 43.67%
# Run 3, Epoch 16, Loss: 2.0008, Training Accuracy: 44.59%
# Run 3, Epoch 17, Loss: 1.9507, Training Accuracy: 46.02%
# Run 3, Epoch 18, Loss: 1.8968, Training Accuracy: 47.48%
# Run 3, Epoch 19, Loss: 1.8361, Training Accuracy: 48.35%
# Run 3, Epoch 20, Loss: 1.7835, Training Accuracy: 49.45%
# Saved checkpoint: checkpoints/checkpoint_run2_epoch20.pth
# Run 3, Epoch 21, Loss: 1.7411, Training Accuracy: 50.52%
# Run 3, Epoch 22, Loss: 1.6972, Training Accuracy: 51.60%
# Run 3, Epoch 23, Loss: 1.6374, Training Accuracy: 52.76%
# Run 3, Epoch 24, Loss: 1.6036, Training Accuracy: 53.67%
# Run 3, Epoch 25, Loss: 1.5567, Training Accuracy: 54.82%
# Run 3, Epoch 26, Loss: 1.5268, Training Accuracy: 55.40%
# Run 3, Epoch 27, Loss: 1.4851, Training Accuracy: 56.51%
# Run 3, Epoch 28, Loss: 1.4487, Training Accuracy: 57.07%
# Run 3, Epoch 29, Loss: 1.4250, Training Accuracy: 57.85%
# Run 3, Epoch 30, Loss: 1.3820, Training Accuracy: 58.67%
# Saved checkpoint: checkpoints/checkpoint_run2_epoch30.pth
# Run 3, Epoch 31, Loss: 1.3570, Training Accuracy: 59.69%
# Run 3, Epoch 32, Loss: 1.3231, Training Accuracy: 60.47%
# Run 3, Epoch 33, Loss: 1.2911, Training Accuracy: 61.05%
# Run 3, Epoch 34, Loss: 1.2770, Training Accuracy: 61.57%
# Run 3, Epoch 35, Loss: 1.2353, Training Accuracy: 62.90%
# Run 3, Epoch 36, Loss: 1.2108, Training Accuracy: 63.45%
# Run 3, Epoch 37, Loss: 1.1948, Training Accuracy: 63.80%
# Run 3, Epoch 38, Loss: 1.1573, Training Accuracy: 64.64%
# Run 3, Epoch 39, Loss: 1.1497, Training Accuracy: 65.19%
# Run 3, Epoch 40, Loss: 1.1289, Training Accuracy: 65.61%
# Saved checkpoint: checkpoints/checkpoint_run2_epoch40.pth
# Run 3, Epoch 41, Loss: 1.1016, Training Accuracy: 66.19%
# Run 3, Epoch 42, Loss: 1.0782, Training Accuracy: 66.81%
# Run 3, Epoch 43, Loss: 1.0765, Training Accuracy: 66.79%
# Run 3, Epoch 44, Loss: 1.0496, Training Accuracy: 67.42%
# Run 3, Epoch 45, Loss: 1.0313, Training Accuracy: 68.10%
# Run 3, Epoch 46, Loss: 1.0109, Training Accuracy: 68.62%
# Run 3, Epoch 47, Loss: 0.9992, Training Accuracy: 69.02%
# Run 3, Epoch 48, Loss: 0.9751, Training Accuracy: 69.85%
# Run 3, Epoch 49, Loss: 0.9700, Training Accuracy: 69.88%
# Run 3, Epoch 50, Loss: 0.9545, Training Accuracy: 70.28%
# Saved checkpoint: checkpoints/checkpoint_run2_epoch50.pth
# Run 3, Epoch 51, Loss: 0.9317, Training Accuracy: 70.89%
# Run 3, Epoch 52, Loss: 0.9276, Training Accuracy: 71.10%
# Run 3, Epoch 53, Loss: 0.9133, Training Accuracy: 71.37%
# Run 3, Epoch 54, Loss: 0.8994, Training Accuracy: 71.84%
# Run 3, Epoch 55, Loss: 0.8972, Training Accuracy: 71.91%
# Run 3, Epoch 56, Loss: 0.8785, Training Accuracy: 72.66%
# Run 3, Epoch 57, Loss: 0.8718, Training Accuracy: 72.78%
# Run 3, Epoch 58, Loss: 0.8535, Training Accuracy: 73.25%
# Run 3, Epoch 59, Loss: 0.8483, Training Accuracy: 73.47%
# Run 3, Epoch 60, Loss: 0.8417, Training Accuracy: 73.68%
# Saved checkpoint: checkpoints/checkpoint_run2_epoch60.pth
# Run 3, Epoch 61, Loss: 0.8316, Training Accuracy: 73.96%
# Run 3, Epoch 62, Loss: 0.8123, Training Accuracy: 74.39%
# Run 3, Epoch 63, Loss: 0.8098, Training Accuracy: 74.78%
# Run 3, Epoch 64, Loss: 0.8020, Training Accuracy: 74.69%
# Run 3, Epoch 65, Loss: 0.7935, Training Accuracy: 75.02%
# Run 3, Epoch 66, Loss: 0.7866, Training Accuracy: 75.32%
# Run 3, Epoch 67, Loss: 0.7801, Training Accuracy: 75.28%
# Run 3, Epoch 68, Loss: 0.7681, Training Accuracy: 75.83%
# Run 3, Epoch 69, Loss: 0.7799, Training Accuracy: 75.63%
# Run 3, Epoch 70, Loss: 0.7513, Training Accuracy: 76.37%
# Saved checkpoint: checkpoints/checkpoint_run2_epoch70.pth
# Run 3, Epoch 71, Loss: 0.7445, Training Accuracy: 76.53%
# Run 3, Epoch 72, Loss: 0.7458, Training Accuracy: 76.49%
# Run 3, Epoch 73, Loss: 0.7355, Training Accuracy: 76.88%
# Run 3, Epoch 74, Loss: 0.7351, Training Accuracy: 76.83%
# Run 3, Epoch 75, Loss: 0.7257, Training Accuracy: 77.09%
# Run 3, Epoch 76, Loss: 0.7141, Training Accuracy: 77.42%
# Run 3, Epoch 77, Loss: 0.7125, Training Accuracy: 77.54%
# Run 3, Epoch 78, Loss: 0.7094, Training Accuracy: 77.58%
# Run 3, Epoch 79, Loss: 0.6993, Training Accuracy: 78.17%
# Run 3, Epoch 80, Loss: 0.6981, Training Accuracy: 78.04%
# Saved checkpoint: checkpoints/checkpoint_run2_epoch80.pth
# Run 3, Epoch 81, Loss: 0.6863, Training Accuracy: 78.34%
# Run 3, Epoch 82, Loss: 0.6873, Training Accuracy: 78.37%
# Run 3, Epoch 83, Loss: 0.6751, Training Accuracy: 78.84%
# Run 3, Epoch 84, Loss: 0.6741, Training Accuracy: 78.81%
# Run 3, Epoch 85, Loss: 0.6740, Training Accuracy: 78.72%
# Run 3, Epoch 86, Loss: 0.6656, Training Accuracy: 78.96%
# Run 3, Epoch 87, Loss: 0.6565, Training Accuracy: 79.51%
# Run 3, Epoch 88, Loss: 0.6541, Training Accuracy: 79.37%
# Run 3, Epoch 89, Loss: 0.6527, Training Accuracy: 79.63%
# Run 3, Epoch 90, Loss: 0.6479, Training Accuracy: 79.71%
# Saved checkpoint: checkpoints/checkpoint_run2_epoch90.pth
# Run 3, Epoch 91, Loss: 0.6450, Training Accuracy: 79.87%
# Run 3, Epoch 92, Loss: 0.6469, Training Accuracy: 79.66%
# Run 3, Epoch 93, Loss: 0.6398, Training Accuracy: 79.90%
# Run 3, Epoch 94, Loss: 0.6190, Training Accuracy: 80.58%
# Run 3, Epoch 95, Loss: 0.6311, Training Accuracy: 80.24%
# Run 3, Epoch 96, Loss: 0.6248, Training Accuracy: 80.36%
# Run 3, Epoch 97, Loss: 0.6131, Training Accuracy: 80.91%
# Run 3, Epoch 98, Loss: 0.6253, Training Accuracy: 80.44%
# Run 3, Epoch 99, Loss: 0.6037, Training Accuracy: 81.11%
# Run 3, Epoch 100, Loss: 0.6155, Training Accuracy: 80.65%
# Saved checkpoint: checkpoints/checkpoint_run2_epoch100.pth
# Run 3, Epoch 101, Loss: 0.6116, Training Accuracy: 80.93%
# Run 3, Epoch 102, Loss: 0.6030, Training Accuracy: 81.28%
# Run 3, Epoch 103, Loss: 0.6073, Training Accuracy: 80.83%
# Run 3, Epoch 104, Loss: 0.6018, Training Accuracy: 81.15%
# Run 3, Epoch 105, Loss: 0.5753, Training Accuracy: 82.16%
# Run 3, Epoch 106, Loss: 0.5763, Training Accuracy: 82.01%
# Run 3, Epoch 107, Loss: 0.5968, Training Accuracy: 81.40%
# Run 3, Epoch 108, Loss: 0.5848, Training Accuracy: 81.61%
# Run 3, Epoch 109, Loss: 0.5902, Training Accuracy: 81.63%
# Run 3, Epoch 110, Loss: 0.5870, Training Accuracy: 81.47%
# Saved checkpoint: checkpoints/checkpoint_run2_epoch110.pth
# Run 3, Epoch 111, Loss: 0.5777, Training Accuracy: 81.81%
# Run 3, Epoch 112, Loss: 0.5726, Training Accuracy: 82.06%
# Run 3, Epoch 113, Loss: 0.5655, Training Accuracy: 82.47%
# Run 3, Epoch 114, Loss: 0.5699, Training Accuracy: 82.19%
# Run 3, Epoch 115, Loss: 0.5683, Training Accuracy: 82.23%
# Run 3, Epoch 116, Loss: 0.5604, Training Accuracy: 82.43%
# Run 3, Epoch 117, Loss: 0.5563, Training Accuracy: 82.37%
# Run 3, Epoch 118, Loss: 0.5544, Training Accuracy: 82.55%
# Run 3, Epoch 119, Loss: 0.5622, Training Accuracy: 82.45%
# Run 3, Epoch 120, Loss: 0.5424, Training Accuracy: 83.04%
# Saved checkpoint: checkpoints/checkpoint_run2_epoch120.pth
# Run 3, Epoch 121, Loss: 0.5582, Training Accuracy: 82.59%
# Run 3, Epoch 122, Loss: 0.5479, Training Accuracy: 83.04%
# Run 3, Epoch 123, Loss: 0.5425, Training Accuracy: 82.97%
# Run 3, Epoch 124, Loss: 0.5368, Training Accuracy: 83.13%
# Run 3, Epoch 125, Loss: 0.5432, Training Accuracy: 83.05%
# Run 3, Epoch 126, Loss: 0.5357, Training Accuracy: 83.14%
# Run 3, Epoch 127, Loss: 0.5344, Training Accuracy: 83.27%
# Run 3, Epoch 128, Loss: 0.5383, Training Accuracy: 83.06%
# Run 3, Epoch 129, Loss: 0.5110, Training Accuracy: 84.00%
# Run 3, Epoch 130, Loss: 0.5361, Training Accuracy: 83.43%
# Saved checkpoint: checkpoints/checkpoint_run2_epoch130.pth
# Run 3, Epoch 131, Loss: 0.5202, Training Accuracy: 83.73%
# Run 3, Epoch 132, Loss: 0.5233, Training Accuracy: 83.84%
# Run 3, Epoch 133, Loss: 0.5210, Training Accuracy: 83.79%
# Run 3, Epoch 134, Loss: 0.5237, Training Accuracy: 83.64%
# Run 3, Epoch 135, Loss: 0.5185, Training Accuracy: 84.12%
# Run 3, Epoch 136, Loss: 0.5126, Training Accuracy: 84.15%
# Run 3, Epoch 137, Loss: 0.5095, Training Accuracy: 84.22%
# Run 3, Epoch 138, Loss: 0.5137, Training Accuracy: 84.06%
# Run 3, Epoch 139, Loss: 0.5167, Training Accuracy: 83.99%
# Run 3, Epoch 140, Loss: 0.5165, Training Accuracy: 83.98%
# Saved checkpoint: checkpoints/checkpoint_run2_epoch140.pth
# Run 3, Epoch 141, Loss: 0.5047, Training Accuracy: 84.53%
# Run 3, Epoch 142, Loss: 0.5128, Training Accuracy: 84.48%
# Run 3, Epoch 143, Loss: 0.4984, Training Accuracy: 84.56%
# Run 3, Epoch 144, Loss: 0.5025, Training Accuracy: 84.31%
# Run 3, Epoch 145, Loss: 0.4982, Training Accuracy: 84.58%
# Run 3, Epoch 146, Loss: 0.4974, Training Accuracy: 84.68%
# Run 3, Epoch 147, Loss: 0.4932, Training Accuracy: 84.43%
# Run 3, Epoch 148, Loss: 0.4888, Training Accuracy: 84.73%
# Run 3, Epoch 149, Loss: 0.4952, Training Accuracy: 84.76%
# Run 3, Epoch 150, Loss: 0.4958, Training Accuracy: 84.56%
# Saved checkpoint: checkpoints/checkpoint_run2_epoch150.pth
# Run 3, Epoch 151, Loss: 0.4869, Training Accuracy: 84.90%
# Run 3, Epoch 152, Loss: 0.4853, Training Accuracy: 85.03%
# Run 3, Epoch 153, Loss: 0.4778, Training Accuracy: 85.03%
# Run 3, Epoch 154, Loss: 0.4752, Training Accuracy: 85.32%
# Run 3, Epoch 155, Loss: 0.4867, Training Accuracy: 84.83%
# Run 3, Epoch 156, Loss: 0.4863, Training Accuracy: 85.05%
# Run 3, Epoch 157, Loss: 0.4722, Training Accuracy: 85.36%
# Run 3, Epoch 158, Loss: 0.4794, Training Accuracy: 85.14%
# Run 3, Epoch 159, Loss: 0.4812, Training Accuracy: 85.03%
# Run 3, Epoch 160, Loss: 0.4753, Training Accuracy: 85.35%
# Saved checkpoint: checkpoints/checkpoint_run2_epoch160.pth
# Run 3, Epoch 161, Loss: 0.4716, Training Accuracy: 85.41%
# Run 3, Epoch 162, Loss: 0.4668, Training Accuracy: 85.47%
# Run 3, Epoch 163, Loss: 0.4784, Training Accuracy: 85.30%
# Run 3, Epoch 164, Loss: 0.4708, Training Accuracy: 85.47%
# Run 3, Epoch 165, Loss: 0.4670, Training Accuracy: 85.51%
# Run 3, Epoch 166, Loss: 0.4681, Training Accuracy: 85.54%
# Run 3, Epoch 167, Loss: 0.4542, Training Accuracy: 85.90%
# Run 3, Epoch 168, Loss: 0.4525, Training Accuracy: 85.90%
# Run 3, Epoch 169, Loss: 0.4659, Training Accuracy: 85.80%
# Run 3, Epoch 170, Loss: 0.4665, Training Accuracy: 85.55%
# Saved checkpoint: checkpoints/checkpoint_run2_epoch170.pth
# Run 3, Epoch 171, Loss: 0.4620, Training Accuracy: 85.71%
# Run 3, Epoch 172, Loss: 0.4603, Training Accuracy: 85.64%
# Run 3, Epoch 173, Loss: 0.4574, Training Accuracy: 85.89%
# Run 3, Epoch 174, Loss: 0.4613, Training Accuracy: 85.80%
# Run 3, Epoch 175, Loss: 0.4619, Training Accuracy: 85.57%
#
# Results after Run 3:
# Training Losses: [4.205573208801582, 3.633271284115589, 3.327335482058318, 3.1151111781444696, 2.9502847725168215, 2.8098346110804915, 2.6934926601322107, 2.5849507336726276, 2.497496248358656, 2.405527023708119, 2.326209044365017, 2.2595887816775484, 2.181131488069549, 2.1269523419077743, 2.0603299951919203, 2.00076519391116, 1.9507217375213837, 1.8968099410576589, 1.8360678460591895, 1.7835493914001739, 1.741144331824749, 1.6972219893694533, 1.6373736160185637, 1.603612405564779, 1.556749775129206, 1.5268163552979375, 1.4851028862054392, 1.4486828867126913, 1.4250148708558144, 1.3819941356206489, 1.3569757984117474, 1.3230547806643465, 1.2911094762480166, 1.276955945488742, 1.2352700250228044, 1.2107657287889124, 1.1947626488288041, 1.1572512400424695, 1.1497140532107, 1.1288694377293063, 1.1016029826820355, 1.0781528893334176, 1.0765034108210707, 1.0496436927629553, 1.0313324454952688, 1.0109463933178835, 0.9991794313921039, 0.975135875937274, 0.9700178423196154, 0.954540523726617, 0.9316503109834383, 0.9275774507952468, 0.9133176788725816, 0.8993602100845492, 0.8972236123269476, 0.8784775502617707, 0.8718131638853751, 0.8534535298033443, 0.8483234845921207, 0.8416531306627156, 0.8315855106124488, 0.8123138865165394, 0.8098197498970934, 0.8019520801580166, 0.7934691441790832, 0.78658986804278, 0.7800636196990147, 0.7681398028912751, 0.7799261091539013, 0.7512533938335946, 0.7445201484291145, 0.7457818175139634, 0.7355233462875151, 0.7350862437044569, 0.7257104581579223, 0.7140891090835757, 0.7124627086969898, 0.7093995645299287, 0.6992842687670228, 0.6980650026703734, 0.6862981793139596, 0.6873247661172887, 0.6750985375603141, 0.674086287084138, 0.6740220927292734, 0.665633251066403, 0.6564795749114297, 0.6540548971203892, 0.6526638974466592, 0.6478817951115196, 0.6450356467605551, 0.646877628801119, 0.6398266521484955, 0.6189939425043438, 0.6310796054732769, 0.6247659059398619, 0.6131283545585544, 0.6253391296967216, 0.6036754605905784, 0.6155492238833776, 0.6115957316001663, 0.6030267530199512, 0.6073302360789855, 0.6018236160964308, 0.5752681391242215, 0.5763137098163595, 0.5967851703048057, 0.5847867328645019, 0.5901752980354497, 0.5869704957889474, 0.5777411866180427, 0.5726452096534507, 0.565520002370905, 0.5698737019620588, 0.5683183989599537, 0.5604440902009644, 0.5562778932740317, 0.5543506126422102, 0.562164735649248, 0.5424310948004198, 0.5581592521284853, 0.5479438587299088, 0.5424674200013165, 0.5367854004320891, 0.5432458988883916, 0.5356804607126414, 0.5344046258255649, 0.53830812364588, 0.5110244328141822, 0.5360965502002965, 0.520168598693655, 0.5233427841225853, 0.5210257786161759, 0.5236914249522912, 0.5184570202399092, 0.512624788009907, 0.5094738348060862, 0.5137297213077545, 0.5167477945308856, 0.5164639688551883, 0.504684430844796, 0.5127788194457589, 0.49842202570051186, 0.5025164659713846, 0.4982453605250629, 0.4974202748835849, 0.4931612403210624, 0.48875504705454687, 0.4952388616931408, 0.49578113126975804, 0.4869145242987996, 0.48534459971329746, 0.4777966547766915, 0.47522942623709474, 0.4866620549917831, 0.48632540980644545, 0.47222938413357796, 0.47942573802016886, 0.48115297477416064, 0.475300395484928, 0.4716085005846932, 0.46682543162723333, 0.47836837271595245, 0.47082567026319405, 0.4670042564992405, 0.46808120282485965, 0.4542481606573705, 0.4524653538242173, 0.465865905499062, 0.46651991633960355, 0.4620231989666324, 0.4603481928786963, 0.45742354370520244, 0.46128105351229765, 0.4619216751164335]
# ...
# Saved checkpoint: checkpoints/checkpoint_run4_epoch130.pth
# Run 5, Epoch 131, Loss: 0.8651, Training Accuracy: 73.18%
# Run 5, Epoch 132, Loss: 0.8629, Training Accuracy: 73.52%
# Run 5, Epoch 133, Loss: 0.8593, Training Accuracy: 73.43%
# Run 5, Epoch 134, Loss: 0.8436, Training Accuracy: 74.01%
# Run 5, Epoch 135, Loss: 0.8491, Training Accuracy: 73.63%
# Run 5, Epoch 136, Loss: 0.8494, Training Accuracy: 73.79%
# Run 5, Epoch 137, Loss: 0.8289, Training Accuracy: 74.40%
# Run 5, Epoch 138, Loss: 0.8437, Training Accuracy: 73.95%
# Run 5, Epoch 139, Loss: 0.8419, Training Accuracy: 73.82%
# Run 5, Epoch 140, Loss: 0.8410, Training Accuracy: 73.80%
# Saved checkpoint: checkpoints/checkpoint_run4_epoch140.pth
# Run 5, Epoch 141, Loss: 0.8445, Training Accuracy: 74.02%
# Run 5, Epoch 142, Loss: 0.8340, Training Accuracy: 74.22%
# Run 5, Epoch 143, Loss: 0.8270, Training Accuracy: 74.49%
# Run 5, Epoch 144, Loss: 0.8375, Training Accuracy: 74.30%
# Run 5, Epoch 145, Loss: 0.8272, Training Accuracy: 74.61%
# Run 5, Epoch 146, Loss: 0.8233, Training Accuracy: 74.76%
# Run 5, Epoch 147, Loss: 0.8270, Training Accuracy: 74.53%
# Run 5, Epoch 148, Loss: 0.8256, Training Accuracy: 74.60%
# Run 5, Epoch 149, Loss: 0.8109, Training Accuracy: 74.91%
# Run 5, Epoch 150, Loss: 0.8158, Training Accuracy: 74.84%
# Saved checkpoint: checkpoints/checkpoint_run4_epoch150.pth
# Run 5, Epoch 151, Loss: 0.8211, Training Accuracy: 74.92%
# Run 5, Epoch 152, Loss: 0.8083, Training Accuracy: 75.24%
# Run 5, Epoch 153, Loss: 0.8043, Training Accuracy: 74.98%
# Run 5, Epoch 154, Loss: 0.8075, Training Accuracy: 74.97%
# Run 5, Epoch 155, Loss: 0.8109, Training Accuracy: 74.95%
# Run 5, Epoch 156, Loss: 0.7922, Training Accuracy: 75.57%
# Run 5, Epoch 157, Loss: 0.8037, Training Accuracy: 75.29%
# Run 5, Epoch 158, Loss: 0.8031, Training Accuracy: 75.19%
# Run 5, Epoch 159, Loss: 0.7977, Training Accuracy: 75.35%
# Run 5, Epoch 160, Loss: 0.7921, Training Accuracy: 75.49%
# Saved checkpoint: checkpoints/checkpoint_run4_epoch160.pth
# Run 5, Epoch 161, Loss: 0.7961, Training Accuracy: 75.46%
# Run 5, Epoch 162, Loss: 0.7819, Training Accuracy: 76.02%
# Run 5, Epoch 163, Loss: 0.7948, Training Accuracy: 75.33%
# Run 5, Epoch 164, Loss: 0.7911, Training Accuracy: 75.61%
# Run 5, Epoch 165, Loss: 0.7895, Training Accuracy: 75.59%
# Run 5, Epoch 166, Loss: 0.7785, Training Accuracy: 75.92%
# Run 5, Epoch 167, Loss: 0.7899, Training Accuracy: 75.73%
# Run 5, Epoch 168, Loss: 0.7826, Training Accuracy: 75.92%
# Run 5, Epoch 169, Loss: 0.7829, Training Accuracy: 76.03%
# Run 5, Epoch 170, Loss: 0.7737, Training Accuracy: 76.00%
# Saved checkpoint: checkpoints/checkpoint_run4_epoch170.pth
# Run 5, Epoch 171, Loss: 0.7743, Training Accuracy: 76.16%
# Run 5, Epoch 172, Loss: 0.7564, Training Accuracy: 76.55%
# Run 5, Epoch 173, Loss: 0.7724, Training Accuracy: 76.21%
# Run 5, Epoch 174, Loss: 0.7718, Training Accuracy: 76.26%
# Run 5, Epoch 175, Loss: 0.7828, Training Accuracy: 75.94%
#
# Results after Run 5:
# Training Losses: [4.221357790100605, 3.7218844677176315, 3.4182313985531896, 3.201747306167622, 3.045052992718299, 2.920513557656037, 2.820886436935581, 2.7365356528240703, 2.6472073884876184, 2.5814630175795394, 2.5072694922347205, 2.4540116521708497, 2.399108714459802, 2.338302466113244, 2.290978348316134, 2.2516086526843897, 2.206831843194449, 2.1644978152821435, 2.1222626798598054, 2.082087509619915, 2.0399217419612135, 2.0211929686539007, 1.9742365093792187, 1.9526574529345384, 1.9081578160185948, 1.8799147297964072, 1.846587676373894, 1.8151408584831317, 1.7877647582527316, 1.7606559289081016, 1.732811675961975, 1.706627953083009, 1.6790613850669178, 1.6618535898225693, 1.641040364494714, 1.61944301262536, 1.5932679286850688, 1.5800860664423775, 1.547031250146344, 1.53544086195014, 1.5148923920700923, 1.49618258698822, 1.4859137660859492, 1.4551521811034063, 1.4419707908197437, 1.4314498465384364, 1.4160987058716357, 1.3897726862784237, 1.3771851222838283, 1.3553168873500336, 1.3520568464418201, 1.3319587088606852, 1.3259521527668399, 1.315650806173949, 1.2956970318808885, 1.2866807286544224, 1.27414500675238, 1.2705305172201922, 1.2501967901464008, 1.2500565173223501, 1.2364395256999814, 1.2151274612492613, 1.20940691895802, 1.2008531400767128, 1.1945360046061104, 1.1824971648585765, 1.170320987015429, 1.156701194584522, 1.1657067666120846, 1.1645017347829727, 1.141075346094873, 1.134909683100098, 1.1295757290652342, 1.1225837572761204, 1.1136491538770974, 1.1035498316635561, 1.1021408838841615, 1.0971365349219584, 1.0908868094844282, 1.0798554809197136, 1.068521781117105, 1.0668739093386608, 1.0594509898701592, 1.066115896948768, 1.0447227806996202, 1.0381457557153824, 1.040318872655749, 1.0238765283771183, 1.0356649616947564, 1.0143973166527955, 1.0192395090447057, 1.0093811018692562, 1.0089635072309342, 1.00655800378536, 0.9996963879641365, 1.0005418906736252, 0.9882489009891324, 0.9776434821774588, 0.9778079366516275, 0.9718457207350475, 0.974407818844861, 0.9620380947352065, 0.9636389237002033, 0.9596617309867269, 0.9511040211333643, 0.9514921196281453, 0.9514006978029486, 0.9407400587559356, 0.9302676044156789, 0.9305431035625965, 0.9272057009322564, 0.9247549259296769, 0.9233144215305747, 0.919839661596986, 0.9117518898928562, 0.9126177087921621, 0.9070699731712146, 0.915719071541296, 0.8988394222753432, 0.902008558592528, 0.8914483015799461, 0.8903736624952472, 0.8973198360037011, 0.9011518616048272, 0.8805106807776424, 0.8697905553042736, 0.8784319316334737, 0.8908624174573537, 0.8692539153272844, 0.8711562865911542, 0.8650890700804913, 0.8628890475501185, 0.8592613659932485, 0.843560980942548, 0.8491170795067496, 0.8493857321226993, 0.828882376327539, 0.8436867802039437, 0.8418619881962877, 0.8409506216302247, 0.8444874359061346, 0.8340065224320078, 0.8269588999507372, 0.8374625646778385, 0.8272482908290365, 0.823287974461875, 0.8269785482179174, 0.8256055142187402, 0.810882478075869, 0.8158098955822113, 0.8211064736556519, 0.8083077815868666, 0.8043425690639964, 0.807525076334129, 0.8109030450701409, 0.7921849944631157, 0.8036661181608429, 0.8031092000282024, 0.7977309821892882, 0.7920998774297402, 0.7960904434971188, 0.7818876319300488, 0.7947577064680627, 0.7910621193668727, 0.7895437772469143, 0.7785187916225179, 0.7899032380727246, 0.7826277114393766, 0.7829036690923564, 0.7737148732251828, 0.7742692621239006, 0.756435310482369, 0.7724219865125158, 0.7718292408815736, 0.78283056799713]
# Training Accuracies: [4.574, 11.174, 16.762, 20.72, 23.954, 26.084, 28.144, 29.792, 31.656, 33.018, 34.484, 35.66, 36.712, 37.794, 38.702, 39.976, 40.89, 41.686, 42.662, 43.534, 44.19, 44.432, 45.556, 46.22, 46.862, 47.418, 48.424, 48.83, 49.596, 50.262, 51.14, 51.468, 51.974, 52.496, 52.662, 53.158, 53.876, 54.12, 55.198, 55.396, 55.884, 56.018, 56.678, 56.792, 57.912, 57.646, 58.216, 58.724, 58.918, 59.554, 59.506, 60.338, 60.31, 60.534, 61.082, 61.418, 61.586, 61.82, 62.344, 62.254, 62.492, 63.37, 63.498, 63.6, 63.904, 64.082, 64.564, 65.038, 64.556, 64.784, 65.122, 65.376, 65.424, 65.734, 65.96, 66.284, 66.632, 66.212, 66.716, 67.076, 67.458, 67.246, 67.55, 67.53, 68.022, 68.21, 68.222, 68.388, 68.194, 68.826, 68.598, 69.15, 69.074, 68.996, 69.362, 69.356, 69.612, 69.564, 69.96, 70.154, 70.116, 70.422, 70.306, 70.638, 70.84, 70.76, 70.544, 71.11, 71.306, 71.354, 71.362, 71.458, 71.534, 71.396, 72.038, 71.794, 72.044, 72.088, 72.358, 72.05, 72.372, 72.546, 72.304, 72.458, 72.688, 73.174, 72.912, 72.79, 73.188, 73.26, 73.182, 73.52, 73.432, 74.008, 73.63, 73.786, 74.4, 73.954, 73.824, 73.798, 74.024, 74.222, 74.486, 74.302, 74.606, 74.762, 74.532, 74.596, 74.91, 74.844, 74.924, 75.244, 74.978, 74.974, 74.95, 75.574, 75.294, 75.19, 75.346, 75.49, 75.46, 76.016, 75.334, 75.614, 75.588, 75.92, 75.73, 75.924, 76.03, 76.004, 76.158, 76.55, 76.206, 76.256, 75.944]
# Test Accuracy: 42.66
# Saved checkpoint: checkpoints/checkpoint_run4_epoch175.pth
#
# Aggregated Results:
# All Training Losses over Epochs for each run: [[4.203888251653413, 3.6582889038583506, 3.340076491655901, 3.1014670618354816, 2.9237968632022437, 2.7818099836559247, 2.66510353140209, 2.5716895973286054, 2.490488011361388, 2.4062194033047124, 2.3431669837983367, 2.287645283257565, 2.2283681833835516, 2.1756959363932498, 2.1294573676555664, 2.0836770847020554, 2.036349105560566, 1.9892777770071688, 1.947455859855008, 1.9222807891838385, 1.8792649217883644, 1.8435723659632457, 1.8129329221023014, 1.7908228155597092, 1.7565203377657839, 1.7222915695756293, 1.7011629989384995, 1.6729237452492385, 1.6478395818749352, 1.6249655533934493, 1.6067317666300118, 1.5818654557932978, 1.565262724828842, 1.5404537892555032, 1.5309691897133733, 1.5026089513240872, 1.4861673921575327, 1.4768416170421463, 1.4637135317563401, 1.442989640376147, 1.4360964478129317, 1.403719976430049, 1.399599027831841, 1.3797600673287727, 1.3702953491369476, 1.3613833931400954, 1.3382222355936495, 1.32108175053316, 1.322940992805964, 1.3000147345730715, 1.2973013409720662, 1.2806803143542747, 1.2729567151392818, 1.266950386945549, 1.2553403781503059, 1.2387471295836028, 1.2490497243678784, 1.225728289474307, 1.217567236069828, 1.2010321802342945, 1.2038687046836405, 1.1960763964811554, 1.179650199763915, 1.172143597051006, 1.1703065598712248, 1.1745002424473043, 1.159511187573528, 1.1509087873846673, 1.133820419878606, 1.1435450404653769, 1.1274999958627365, 1.1213686803875067, 1.1239473630705148, 1.1202302501939447, 1.0998643659569722, 1.0921545506590773, 1.0897732335893089, 1.0753244254595178, 1.0743350864523817, 1.0782766072341547, 1.068977935539792, 1.0637686053657776, 1.0556567759465074, 1.0413691343553841, 1.0463928503301136, 1.0448997975005518, 1.0390973492808964, 1.0362272089552087, 1.0252894990508208, 1.0210987092436428, 1.011993800663887, 1.0175323583890714, 0.9965898656784116, 1.0082526717649396, 0.9944273207498633, 0.9974011846286867, 0.988609178672971, 0.9818832355234629, 0.9865243742075722, 0.9741017857704626, 0.9900044513023113, 0.9780511750513331, 0.9706224089540789, 0.9687080399307144, 0.9716742153057967, 0.9644475603271323, 0.9596697891993291, 0.947945238341151, 0.952652898400336, 0.9436307621505254, 0.9505757448999473, 0.9310110425552749, 0.9416782279377398, 0.9252684109122552, 0.926055316463151, 0.9246938287297173, 0.915854129454364, 0.9230538830732751, 0.9091273489053292, 0.9118457104620117, 0.9179756395957049, 0.9148939197020762, 0.9034031592595303, 0.910131547762, 0.9014445741082091, 0.9055826096888393, 0.8945445401208175, 0.8750458866586466, 0.8954681020106197, 0.8882468351546455, 0.900388492723865, 0.8759331947473614, 0.8850257601350775, 0.881149038748668, 0.8748573307948344, 0.8872953501275128, 0.8635743368236001, 0.8731931705227898, 0.8754017586293428, 0.868926738610353, 0.8549037909187625, 0.8684133838128556, 0.8662306663325375, 0.8594600402409464, 0.8598550384306847, 0.8593413396869474, 0.8528633156548375, 0.8486226473546699, 0.8493452645704874, 0.8629924129799503, 0.8503157185471576, 0.8415090221806866, 0.8385976123840303, 0.8484127719307799, 0.8347056949382547, 0.8336256316403294, 0.8260075416406403, 0.8354918255144373, 0.8224897067946242, 0.8093598551305053, 0.8319833944063357, 0.827760191029295, 0.814402061121543, 0.8231647799310782, 0.8300954650353898, 0.8054535742992025, 0.824886218208791, 0.8274445902279881, 0.8113518724661044, 0.8220428979534018, 0.8058665263302186, 0.8096291986496552, 0.8126240519382765, 0.825190314399007, 0.8161208171140203], [4.177533014351145, 3.6492984581481465, 3.343029891133613, 3.134077124278564, 2.9724115044869426, 2.8413528493603173, 2.725267259361189, 2.618562412993682, 2.5423795335433064, 2.459252940266943, 2.3877767623233064, 2.3214120837428687, 2.254122733764941, 2.1884908979506137, 2.1332187433072063, 2.0781021952019323, 2.0304729284532845, 1.9841869691448748, 1.94262206569657, 1.8927319679418793, 1.8463989985568443, 1.8016761431608663, 1.7705969824205579, 1.7207213051788641, 1.6858401612552536, ...
# All Training Accuracies over Epochs for each run: [[4.702, 12.356, 18.276, 22.898, 26.334, 28.87, 31.174, 33.118, 34.722, 36.44, 37.83, 38.842, 40.016, 41.118, 41.97, 43.002, 43.96, 45.048, 46.05, 46.258, 47.478, 48.29, 49.086, 49.248, 50.3, 50.766, 51.378, 52.11, 52.698, 53.282, 53.576, 53.952, 54.384, 55.24, 55.504, 56.034, 56.438, 56.708, 56.978, 57.322, 57.976, 58.934, 58.72, 59.424, 59.484, 59.68, 60.076, 60.876, 60.594, 61.238, 61.208, 61.878, 61.95, 62.16, 62.656, 62.85, 62.848, 63.318, 63.592, 63.842, 64.128, 64.102, 64.96, 64.524, 64.73, 64.792, 65.338, 65.736, 65.918, 65.728, 66.056, 66.352, 66.284, 66.562, 66.922, 67.082, 67.016, 67.604, 67.8, 67.488, 68.042, 68.07, 68.31, 68.432, 68.622, 68.61, 68.786, 68.672, 68.868, 69.366, 69.738, 69.346, 69.952, 69.702, 69.902, 70.166, 70.24, 70.602, 70.254, 70.86, 70.294, 70.334, 70.56, 71.0, 70.784, 71.364, 71.08, 71.326, 71.358, 71.404, 71.744, 71.874, 71.854, 72.374, 72.094, 72.232, 72.592, 72.482, 72.822, 72.612, 72.54, 72.834, 72.924, 72.86, 73.124, 72.832, 73.302, 73.64, 73.248, 73.622, 72.99, 73.722, 73.634, 73.618, 73.842, 73.598, 74.014, 74.042, 73.89, 74.108, 74.404, 74.018, 73.996, 74.264, 74.476, 74.388, 74.402, 74.578, 74.798, 74.49, 74.558, 74.756, 75.122, 74.654, 75.148, 74.932, 75.374, 75.15, 75.208, 75.892, 75.234, 75.368, 75.646, 75.462, 75.256, 75.894, 75.436, 75.29, 75.736, 75.486, 75.998, 75.75, 75.738, 75.428, 75.752], [5.176, 12.402, 18.162, 21.892, 24.858, 27.596, 29.606, 31.82, 33.608, 35.502, 36.896, 38.262, 39.564, 40.96, 42.168, 43.206, 44.006, 45.048, 46.124, 47.222, 48.292, 49.106, 49.826, 50.836, 51.722, 52.462, 53.326, 54.058, 54.846, 55.562, 56.196, 57.004, 57.81, 58.422, 58.91, 59.826, 59.874, 60.984, 61.478, 62.112, 62.728, 62.754, 63.328, 64.076, 64.578, 65.104, 65.382, 65.676, 66.308, 66.818, 67.102, 67.342, 67.62, 68.158, 68.356, 68.864, 68.876, 69.154, 69.718, 69.762, 70.32, 70.57, 70.87, 71.334, 71.346, 71.608, 71.768, 71.9, 72.084, 72.588, 72.942, 73.162, 73.338, 73.426, 73.83, 73.82, 73.72, 73.976, 74.272, 74.302, 74.478, 75.02, 75.04, 75.294, 75.374, 75.342, 75.46, 76.082, 75.826, 75.89, 76.658, 76.324, 76.61, 76.78, 76.724, 76.99, 77.204, 77.21, 77.464, 77.574, 77.666, 77.52, 77.826, 77.88, 78.202, 78.358, 78.344, 78.252, 78.528, 78.892, 78.722, 78.694, 78.832, 78.938, 79.172, 79.024, 79.644, 79.646, 79.272, 79.478, 79.808, 79.822, 79.86, 79.826, 80.122, 79.724, 79.938, 80.398, 80.502, 80.204, 80.492, 80.482, 80.008, 80.644, 81.056, 80.658, 81.076, 80.636, 81.084, 81.488, 80.552, 81.38, 80.83, 81.476, 81.0, 81.442, 81.666, 81.818, 81.65, 81.494, 81.272, 81.712, 81.686, 81.722, 81.722, 82.07, 81.736, 82.268, 82.43, 82.352, 82.096, 82.608, 82.012, 82.378, 82.764, 82.176, 82.54, 82.232, 82.71, 82.44, 82.582, 82.866, 82.746, 82.826, 82.836], [4.75, 12.512, 18.212, 22.276, 25.098, 28.242, 30.432, 32.938, 34.542, 36.29, 38.166, 39.52, 40.868, 42.106, 43.668, 44.586, 46.016, 47.484, 48.352, 49.454, 50.524, 51.598, 52.764, 53.666, 54.82, 55.398, 56.508, 57.074, 57.85, 58.67, 59.686, 60.468, 61.054, 61.568, 62.902, 63.454, 63.798, 64.638, 65.194, 65.614, 66.194, 66.814, 66.794, 67.416, 68.096, 68.62, 69.016, 69.848, 69.876, 70.282, 70.892, 71.102, 71.368, 71.84, 71.91, 72.66, 72.778, 73.254, 73.466, 73.682, 73.958, 74.388, 74.776, 74.69, 75.018, 75.322, 75.278, 75.832, 75.632, 76.368, 76.534, 76.486, 76.878, 76.834, 77.088, 77.416, 77.536, 77.576, 78.166, 78.036, 78.34, 78.372, 78.838, 78.808, 78.724, 78.962, 79.514, 79.37, 79.634, 79.708, 79.874, 79.662, 79.902, 80.578, 80.238, 80.362, 80.914, 80.438, 81.108, 80.652, 80.93, 81.28, 80.828, 81.148, 82.164, 82.014, 81.398, 81.614, 81.626, 81.474, 81.806, 82.064, 82.472, 82.192, 82.23, 82.43, 82.374, 82.55, 82.446, 83.038, 82.588, 83.038, 82.974, 83.134, 83.054, 83.144, 83.274, 83.062, 84.0, 83.428, 83.728, 83.84, 83.788, 83.64, 84.12, 84.146, 84.218, 84.062, 83.99, 83.982, 84.526, 84.478, 84.564, 84.314, 84.584, 84.676, 84.428, 84.728, 84.758, 84.564, 84.9, 85.026, 85.034, 85.322, 84.834, 85.05 ...
# All Test Accuracies for each run: [40.13, 42.83, 42.75, 43.28, 42.66]
